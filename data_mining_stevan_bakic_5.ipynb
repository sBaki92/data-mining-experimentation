# %% [markdown]
# ### Sequence Clustering

# %% [markdown]
# This notebook aims to experiment with clustering different character sequences.

# %%
import numpy as np
import random

# %% [markdown]
# To achieve this, we will compare words (finite sequences of letters) using the Edit Distance, a metric that quantifies the minimum number of operations (insertions, deletions, or substitutions) required to transform one sequence into another.

# %% [markdown]
# While the recursive algorithm for calculating the Edit Distance works, we observed that it often performs redundant and unnecessary calculations. To address this, we implement memoization, a technique that stores intermediate results to avoid redundant computations. This optimization reduces the complexity to O(n × m), where n=∣u∣ and m=∣v∣ represent the lengths of the sequences being compared.

# %%
def edit_distance(seq1, seq2):
    seq1 = seq1.split()
    seq2 = seq2.split()
    
    memo = {}

    def dist(i, j):
        if (i, j) in memo:
            return memo[(i, j)]

        if i == len(seq1):
            return len(seq2) - j
        if j == len(seq2):
            return len(seq1) - i

        if seq1[i] == seq2[j]:
            memo[(i, j)] = dist(i + 1, j + 1)
        else:
            insert = dist(i, j + 1)
            delete = dist(i + 1, j)
            substitute = dist(i + 1, j + 1)
            memo[(i, j)] = 1 + min(insert, delete, substitute)

        return memo[(i, j)]

    return dist(0, 0)

# %%
edit_distance('A C JM JO JU KD JW KB KE KC JZ JX JV JP KF KH KQ LF KJ LB LJ KK LM LD KI LE LK KL LC LG KR KO KN KP KM KG JN D B',
              'A C JM JO JU KD JW BK KE KC JZ JX JV JP KF KH KQ FO KJ LB LJ KK LM D KI LE LK KL LC LG R KO KN KP KM KG JN D B')
# Out:
# 4

# %% [markdown]
# #### Clustering with the k-Medoids Technique

# %% [markdown]
# We then explore the k-Medoids clustering method, which is conceptually similar to k-Means but differs in how cluster representatives are chosen. Instead of using centroids (barycenters), k-Medoids selects actual data points as cluster representatives, making it more robust to noise and outliers. We also compute silhouette scores to evaluate the quality of the clustering.

# %%
def assign_clusters(sequences, medoids, distance_fn):
    clusters = {medoid: [] for medoid in medoids}
    for seq in sequences:
        closest_medoid = min(medoids, key=lambda m: distance_fn(seq, m))
        clusters[closest_medoid].append(seq)
    return clusters

def calculate_new_medoid(cluster, distance_fn):
    return min(cluster, key=lambda candidate: sum(distance_fn(candidate, seq) for seq in cluster))

def k_medoids(sequences, k, distance_fn, max_iter=200):
    medoids = random.sample(sequences, k)

    for _ in range(max_iter):
        clusters = assign_clusters(sequences, medoids, distance_fn)

        new_medoids = [calculate_new_medoid(cluster, distance_fn) for cluster in clusters.values()]

        if set(new_medoids) == set(medoids):
            break

        medoids = new_medoids

    return clusters, medoids

# %%
def load_sequences(file_path, num_sequences=100):
    with open(file_path, 'r') as file:
        all_sequences = [line.strip() for line in file.readlines()]
        return random.sample(all_sequences, min(len(all_sequences), num_sequences))

# %%
sequences = load_sequences("log.txt", num_sequences=100)

k = 3
clusters, medoids = k_medoids(sequences, k, edit_distance)

print("Results of k-medoid clustering :\n")

for i, (medoid, cluster) in enumerate(clusters.items(), 1):
    print(f"Cluster {i} :")
    print(f"  Medoid: {medoid}")
    print(f"  Number of sequences: {len(cluster)}")
    print(f"  Sequences :")
    
    for seq in cluster:
        print(f"    {seq}")
    
    print("\n" + "-"*50 + "\n")
# Out:
# Results of k-medoid clustering :
#
# Cluster 1 :
#   Medoid: A C E G T V X W U Y AA Z H AC AO AE AQ AG AR AI AP AH AS AF AV AT AD F D B
#   Number of sequences: 65
#   Sequences :
#     A C E G I K M L J H AC AE AO AG AR AQ AI AP AH AS AF AV AT AD F D B
#     A C EC HL HV HX HZ HY HW HM IU IW IX IY JB IZ IV ED D B
#     A C EC FL FS FN FX FU FV FW FZ FQ FP FR FY FT FO FM GC GJ GE GK GG GI GH GF GD GL GN GO GM GW GY HA HB GZ GX ED D B
#     A C EC HL HV HX IB HY HW HM IU JC JG JE JK JI JJ JL JF JH JD IV ED D B
#     A C EC EE EI EM EJ EF EN ER EP EQ ES EO ET EV EX EY EW EU EZ FG FI FJ FK FH FA ED D B
#     A C E G T V W X U Y AA Z H AC AE AO AG AQ AJ AR AP AH AS AF AW AT AD F D B
#     A C E AX CA CR AZ DI CC BB DP CD BH CE DS DR DT BL CF DQ BI DJ CB BC CS BA AY F D B
#     A C E AX CR CA AZ DW BM CG DY CI BO EA DZ CK BR CL EB DX BP CJ BN CH CS BA CB AY F D B
#     A C E AX CR AZ DW CA BB EA DY CG EB CI DZ BH BK CK CL DX BI CJ CS CH BC BA CB AY F D B
#     A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FB FE FD FF FC FA ED D B
#     A C E AX AZ CR CA DW BB CC CD EA DY BD DZ CE EB BF CF DX BG CB BE CS BC BA AY F D B
#     A C EC FL FN FS FX FR FU FW GA FQ FP FV FO FY FT FM GC GJ GE GG GH GK GI GF GD GL GN GO GM GW HC HE HD GX ED D B
#     A C E AX AZ CR CA BM DI CG BW CI DP CL CK BY BZ DS DT DR CJ BX CH DQ DJ BN CB CS BA AY F D B
#     A C E G T V X W U Y AA Z H AC AO AE AR AG AQ AI AP AS AH AF AV AT AD F D B
#     A C EC HL IE IG IP IK II IH IT IR IM IS IL IQ IF HM IU JC JK JE JG JJ JI JL JF JH JD IV ED D B
#     A C EC HL HV HX HZ HY HW HM IU JC JE JG JK JJ JI JF JH JL JD IV ED D B
#     A C EC FL FN FX FS GA FV FR FU FQ FW FP FT FY FO FM GC GJ GE GK GI GG GH GF GD GL GN GO GM GW GY HB HA GZ GX ED D B
#     A C E AX CA AZ CR CG DW BB CI EA DY CL CK BH DZ CJ BL EB CH DX BI CB CS BC BA AY F D B
#     A C EC FL FS FN FX FV GA FP FU FW FR FY FQ FT FO FM GC GJ GE GK GI GG GH GF GD GL GP GQ GM GW HC HE HD GX ED D B
#     A C E G T X W V U Y AA Z H AC AO AE AG AR AQ AJ AP AH AS AF AW AT AD F D B
#     A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FG FJ FI FK FH FA ED D B
#     A C EC HL HN HR HP HT HS HQ HU HO HM IU JC JE JG JK JF JI JJ JL JH JD IV ED D B
#     A C E G T V W X U Y AA Z H AC AO AE AQ AG AR AJ AP AH AF AS AU AT AD F D B
#     A C JM LN LP LO LR LT LU LV LS LW LZ LY LX MA MC MD MB ME MM MP MN MF MR MU MT MS MV MY MW JN D B
#     A C JM LN LQ LO LR LT LU LV LS LW LY LZ LX MA MD MC MB ME MG MH MF MR MU MT MS MV MY MW JN D B
#     A C JM JO JU KB KD JW KC JY KE JX JV JP KF KH LF KQ LH KW KJ KK LI LA KI LG KX KL KO KP KR KN KM KG JN D B
#     A C JM JO JQ JR JS JT JP KF LF KQ KH LJ KS KK LL KJ KU KT KI LK KR KL LG KO KP KN KM KG JN D B
#     A C JM JO JQ JR JS JT JP KF KQ KS KH LF KJ KK LH KU LI KT KI KR LG KL KO KN KP KM KG JN D B
#     A C JM LN LP LO LR LU LT LV LS LW LZ LY LX MA MD MC MB ME MG MH MF MR MU MT MS MV MY MW JN D B
#
# --------------------------------------------------

# %%
def calculate_silhouette_scores(clusters, distance_fn):
    silhouette_scores = {}
    all_sequences = [seq for cluster in clusters.values() for seq in cluster]

    for medoid, cluster in clusters.items():
        for seq in cluster:
            intra_distances = [distance_fn(seq, other_seq) for other_seq in cluster if seq != other_seq]
            a_i = np.mean(intra_distances) if intra_distances else 0
            
            inter_distances = []
            for other_medoid, other_cluster in clusters.items():
                if other_medoid != medoid:
                    inter_distances.append(np.mean([distance_fn(seq, other_seq) for other_seq in other_cluster]))
            b_i = min(inter_distances) if inter_distances else 0
            
            if a_i < b_i:
                s_i = (b_i - a_i) / b_i
            elif a_i > b_i:
                s_i = (b_i - a_i) / a_i
            else:
                s_i = 0 
            
            silhouette_scores[seq] = s_i

    avg_silhouette_scores = {
        medoid: np.mean([silhouette_scores[seq] for seq in cluster])
        for medoid, cluster in clusters.items()
    }

    overall_silhouette_score = np.mean(list(silhouette_scores.values()))

    return silhouette_scores, avg_silhouette_scores, overall_silhouette_score

# %%
silhouette_scores, avg_silhouette_scores, overall_silhouette_score = calculate_silhouette_scores(clusters, edit_distance)

print("Silhouette scores for each point :")
for seq, score in silhouette_scores.items():
    print(f"  Sequence: {seq} -> Silhouette score: {score:.3f}")

print("\nAverage silhouette score per cluster :")
for medoid, score in avg_silhouette_scores.items():
    print(f"  Medoid: {medoid} -> Average score: {score:.3f}")

print(f"\nOverall silhouette score: {overall_silhouette_score:.3f}")
# Out:
# Silhouette scores for each point :
#   Sequence: A C E G I K M L J H AC AE AO AG AR AQ AI AP AH AS AF AV AT AD F D B -> Silhouette score: -0.510
#   Sequence: A C EC HL HV HX HZ HY HW HM IU IW IX IY JB IZ IV ED D B -> Silhouette score: 0.006
#   Sequence: A C EC FL FS FN FX FU FV FW FZ FQ FP FR FY FT FO FM GC GJ GE GK GG GI GH GF GD GL GN GO GM GW GY HA HB GZ GX ED D B -> Silhouette score: 0.099
#   Sequence: A C EC HL HV HX IB HY HW HM IU JC JG JE JK JI JJ JL JF JH JD IV ED D B -> Silhouette score: 0.033
#   Sequence: A C EC EE EI EM EJ EF EN ER EP EQ ES EO ET EV EX EY EW EU EZ FG FI FJ FK FH FA ED D B -> Silhouette score: 0.061
#   Sequence: A C E G T V W X U Y AA Z H AC AE AO AG AQ AJ AR AP AH AS AF AW AT AD F D B -> Silhouette score: -0.560
#   Sequence: A C E AX CA CR AZ DI CC BB DP CD BH CE DS DR DT BL CF DQ BI DJ CB BC CS BA AY F D B -> Silhouette score: -0.022
#   Sequence: A C E AX CR CA AZ DW BM CG DY CI BO EA DZ CK BR CL EB DX BP CJ BN CH CS BA CB AY F D B -> Silhouette score: -0.026
#   Sequence: A C E AX CR AZ DW CA BB EA DY CG EB CI DZ BH BK CK CL DX BI CJ CS CH BC BA CB AY F D B -> Silhouette score: -0.024
#   Sequence: A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FB FE FD FF FC FA ED D B -> Silhouette score: 0.056
#   Sequence: A C E AX AZ CR CA DW BB CC CD EA DY BD DZ CE EB BF CF DX BG CB BE CS BC BA AY F D B -> Silhouette score: -0.019
#   Sequence: A C EC FL FN FS FX FR FU FW GA FQ FP FV FO FY FT FM GC GJ GE GG GH GK GI GF GD GL GN GO GM GW HC HE HD GX ED D B -> Silhouette score: 0.098
#   Sequence: A C E AX AZ CR CA BM DI CG BW CI DP CL CK BY BZ DS DT DR CJ BX CH DQ DJ BN CB CS BA AY F D B -> Silhouette score: -0.007
#   Sequence: A C E G T V X W U Y AA Z H AC AO AE AR AG AQ AI AP AS AH AF AV AT AD F D B -> Silhouette score: -0.479
#   Sequence: A C EC HL IE IG IP IK II IH IT IR IM IS IL IQ IF HM IU JC JK JE JG JJ JI JL JF JH JD IV ED D B -> Silhouette score: 0.051
#   Sequence: A C EC HL HV HX HZ HY HW HM IU JC JE JG JK JJ JI JF JH JL JD IV ED D B -> Silhouette score: 0.035
#   Sequence: A C EC FL FN FX FS GA FV FR FU FQ FW FP FT FY FO FM GC GJ GE GK GI GG GH GF GD GL GN GO GM GW GY HB HA GZ GX ED D B -> Silhouette score: 0.096
#   Sequence: A C E AX CA AZ CR CG DW BB CI EA DY CL CK BH DZ CJ BL EB CH DX BI CB CS BC BA AY F D B -> Silhouette score: -0.017
#   Sequence: A C EC FL FS FN FX FV GA FP FU FW FR FY FQ FT FO FM GC GJ GE GK GI GG GH GF GD GL GP GQ GM GW HC HE HD GX ED D B -> Silhouette score: 0.098
#   Sequence: A C E G T X W V U Y AA Z H AC AO AE AG AR AQ AJ AP AH AS AF AW AT AD F D B -> Silhouette score: -0.496
#   Sequence: A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FG FJ FI FK FH FA ED D B -> Silhouette score: 0.064
#   Sequence: A C EC HL HN HR HP HT HS HQ HU HO HM IU JC JE JG JK JF JI JJ JL JH JD IV ED D B -> Silhouette score: 0.035
#   Sequence: A C E G T V W X U Y AA Z H AC AO AE AQ AG AR AJ AP AH AF AS AU AT AD F D B -> Silhouette score: -0.563
#   Sequence: A C EC FL FS FX FN FZ FQ FU FR FW FY FP FV FO FT FM GC GE GJ GG GK GH GI GF GD GL GP GQ GM GW GY HB HA GZ GX ED D B -> Silhouette score: 0.093
#   Sequence: A C E G T V X W U Y AA Z H AC AE AO AG AR AI AQ AH AP AF AS AU AT AD F D B -> Silhouette score: -0.637
#   Sequence: A C E AX CR AZ CA DW BM CC DY BW EA DZ CD EB CE BZ BY DX CF BX CS CB BN BA AY F D B -> Silhouette score: -0.041
#   Sequence: A C E G I P S Q J H AC AE AO AG AR AQ AI AP AH AS AF AV AT AD F D B -> Silhouette score: -0.509
#   Sequence: A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FG FJ FK FI FH FA ED D B -> Silhouette score: 0.064
#   Sequence: A C EC EE EI EM EJ EF EN ER EP EQ ES EO ET EX EV EY EW EU EZ FG FK FI FJ FH FA ED D B -> Silhouette score: 0.066
#   Sequence: A C E AX AZ CR CA BB DI CG BD DP CM DR BG CQ DT CP DS BF CO BE DQ CN DJ BC CH CS BA CB AY F D B -> Silhouette score: 0.002
#   Sequence: A C E G T V X W U Y AA Z H AC AO AE AQ AG AR AI AP AH AS AF AV AT AD F D B -> Silhouette score: -0.471
#   Sequence: A C EC EE EI EM EJ EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FG FI FJ FK FH FA ED D B -> Silhouette score: 0.059
#   Sequence: A C EC EE EI EL EJ EF EN ER EP ES EQ EO ET EX EV EY EW EU EZ FG FK FJ FI FH FA ED D B -> Silhouette score: 0.058
#   Sequence: A C E AX CA CR AZ CT CC CD BB DE CE BD DH BG CF DG BF DF CB CU BE CS BC BA AY F D B -> Silhouette score: -0.032
#   Sequence: A C E AX CA AZ CR DW CC BB CD DY BD EA CE DZ BF BG EB CF BE DX CB BC CS BA AY F D B -> Silhouette score: -0.017
#   Sequence: A C EC HL HV HX IA HY HW HM IU JC JG JE JK JI JJ JH JF JL JD IV ED D B -> Silhouette score: 0.031
#   Sequence: A C E AX AZ CA CR CC BB DI CD BH CE DK BK CF DM BI CB DO DN BC DL BA DJ CS AY F D B -> Silhouette score: -0.036
#   Sequence: A C E AX AZ CA CR BB CC DW CD BH DY EA BK DZ CE EB BI DX CF BC CS CB BA AY F D B -> Silhouette score: -0.026
#   Sequence: A C E G I P S Q J H AC AO AE AK AR AQ AM AN AP AL AS AF AU AT AD F D B -> Silhouette score: -0.420
#   Sequence: A C EC HL HN HP HT HR HQ HS HU HO HM IU JC JG JE JK JJ JI JF JH JL JD IV ED D B -> Silhouette score: 0.040
#   Sequence: A C E AX AZ CA CR CC BB DW CD BH EA CE DY BK DZ EB CF BI DX CB BC CS BA AY F D B -> Silhouette score: -0.015
#   Sequence: A C EC FL FS FN FU FX FP FR FQ FW GA FV FY FO FT FM GC GJ GE GH GI GK GG GF GD GL GN GO GM GW HG HI HH GX ED D B -> Silhouette score: 0.096
#   Sequence: A C EC HL IE IP IG IK IM II IR IH IL IS IT IQ IF HM IU JC JE JG JK JJ JF JI JH JL JD IV ED D B -> Silhouette score: 0.052
#   Sequence: A C E G I K N L J H AC AE AO AG AQ AR AJ AP AH AS AF AV AT AD F D B -> Silhouette score: -0.510
#   Sequence: A C EC FL FN FS FX FQ FR FV FP GA FU FW FO FY FT FM GC GE GJ GK GG GH GI GF GD GL GN GO GM GW HG HI HH GX ED D B -> Silhouette score: 0.097
#   Sequence: A C EC EE EI EM EJ EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FB FD FE FF FC FA ED D B -> Silhouette score: 0.064
#   Sequence: A C EC FL FS FX FN FW FU FV GB FR FQ FY FT FP FO FM GC GJ GE GK GG GH GI GF GD GL GP GQ GM GW HG HJ HH GX ED D B -> Silhouette score: 0.099
#   Sequence: A C EC HL HN HP HR HT HQ HS HU HO HM IU JC JK JE JG JL JF JJ JI JH JD IV ED D B -> Silhouette score: 0.029
#   Sequence: A C E G T X V W U Y AA Z H AC AO AE AG AQ AR AJ AP AH AS AF AW AT AD F D B -> Silhouette score: -0.510
#   Sequence: A C E AX CA CR AZ CT CC CD BM DE CE BO DH DG BR CF DF CU CB BP CS BN BA AY F D B -> Silhouette score: -0.033
#   Sequence: A C E AX AZ CR CA DI BB CC CD DK BH CE BL DO CF DM BI CB DN DL BC DJ BA CS AY F D B -> Silhouette score: -0.031
#   Sequence: A C E G T V W X U Y AA Z H AC AO AE AQ AK AR AP AM AN AS AV AL AF AT AD F D B -> Silhouette score: -0.458
#   Sequence: A C EC FL FS FN FX FU FW FR FV FP FQ GA FT FY FO FM GC GE GJ GG GK GH GI GF GD GL GP GQ GM GW HC HE HD GX ED D B -> Silhouette score: 0.098
#   Sequence: A C EC HL HN HT HR HP HU HS HQ HO HM IU IW IX IY JA IZ IV ED D B -> Silhouette score: 0.012
#   Sequence: A C E AX CA AZ CR CC BM CT CD BS DE CE DG DH BV CF BU DF BT CB CU BN CS BA AY F D B -> Silhouette score: -0.032
#   Sequence: A C EC HL HN HT HR HP HU HS HQ HO HM IU JC JG JE JJ JK JI JF JH JL JD IV ED D B -> Silhouette score: 0.043
#   Sequence: A C E AX CA AZ CR CC BB DW CD CE BD EA DY CF BF EB DZ BG BE CB DX BC BA CS AY F D B -> Silhouette score: -0.030
#   Sequence: A C EC FL FN FS FR FX FP FU FW FQ FZ FV FO FY FT FM GC GJ GE GK GG GI GH GF GD GL GP GQ GM GW HG HI HH GX ED D B -> Silhouette score: 0.100
#   Sequence: A C E G T V X W U Y AB Z H AC AO AE AR AQ AG AI AP AH AS AF AV AT AD F D B -> Silhouette score: -0.490
#   Sequence: A C EC HL HN HT HR HP HU HS HQ HO HM IU JC JG JE JJ JK JI JH JF JL JD IV ED D B -> Silhouette score: 0.041
#   Sequence: A C E G T V W X U Y AA Z H AC AE AO AG AQ AR AJ AP AH AS AF AW AT AD F D B -> Silhouette score: -0.580
#   Sequence: A C EC EE EI EK EJ EF EN EP ER EQ ES EO ET EV EX EY EW EU EZ FB FF FE FD FC FA ED D B -> Silhouette score: 0.054
#   Sequence: A C E G I P S Q J H AC AO AE AK AQ AR AN AP AM AS AL AW AF AT AD F D B -> Silhouette score: -0.376
#   Sequence: A C E AX CR CA AZ DI BM CG DU BS CM DV BU DJ CQ BV CO CP CS BT CN BN CH BA CB AY F D B -> Silhouette score: -0.039
#   Sequence: A C E G T W X V U Y AB Z H AC AE AO AG AI AR AQ AH AF AP AS AV AT AD F D B -> Silhouette score: 0.598
#   Sequence: A C E G I K M L J H AC AE AO AK AR AQ AP AM AN AS AW AL AT AF AD F D B -> Silhouette score: 0.376
#   Sequence: A C E G T V W X U Y AA Z H AC AE AO AG AR AJ AQ AH AP AF AS AU AT AD F D B -> Silhouette score: 0.590
#   Sequence: A C E G I P S Q J H AC AE AO AG AQ AR AJ AP AH AF AS AW AT AD F D B -> Silhouette score: 0.477
#   Sequence: A C E G T X V W U Y AB Z H AC AE AO AR AG AQ AJ AH AP AF AS AU AT AD F D B -> Silhouette score: 0.563
#   Sequence: A C E G T W X V U Y AB Z H AC AE AO AG AI AR AQ AH AP AF AS AV AT AD F D B -> Silhouette score: 0.629
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LY LZ LX MA MC MD MB ME MI MK MJ MF MR MT MU MS MV MY MW JN D B -> Silhouette score: 0.560
#   Sequence: A C JM LN LP LO LR LU LT LV LS LW LZ LY LX MA MD MC MB ME MI MK MJ MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.569
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LZ LY LX MA MD MC MB ME MM MO MN MF MR MT MU MS MV MX MW JN D B -> Silhouette score: 0.565
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LY LZ LX MA MC MD MB ME MG MH MF MR MT MU MS MV MY MW JN D B -> Silhouette score: 0.575
#   Sequence: A C JM JO JQ JR JS JT JP KF KQ KH LF KS LJ KJ KK LL KU LK KT KI LG KR KL KN KP KO KM KG JN D B -> Silhouette score: 0.134
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LZ LY LX MA MD MC MB ME MM MQ MN MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.589
#   Sequence: A C JM LN LP LO LR LU LT LV LS LW LZ LY LX MA MC MD MB ME MM MQ MN MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.565
#   Sequence: A C JM LN LQ LO LR LT LU LV LS LW LZ LY LX MA MC MD MB ME MG MH MF MR MT MU MS MV MY MW JN D B -> Silhouette score: 0.570
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LY LZ LX MA MC MD MB ME MG MH MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.585
#   Sequence: A C JM LN LQ LO LR LT LU LV LS LW LY LZ LX MA MD MC MB ME MG MH MF MR MT MU MS MV MY MW JN D B -> Silhouette score: 0.575
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LZ LY LX MA MD MC MB ME MG MH MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.600
#   Sequence: A C JM JO JU KB KD JW KC KE JY JX JV JP KF LF KH LH KQ KJ LB KK LI LE LD KI LC LG KL KP KR KN KO KM KG JN D B -> Silhouette score: 0.149
#   Sequence: A C JM JO JU KB KD JW KC KE JZ JX JV JP KF LF KQ KH KS LH KJ KK KV LI KT KI LG KR KL KO KN KP KM KG JN D B -> Silhouette score: 0.165
#   Sequence: A C JM LN LQ LO LR LU LT LV LS LW LZ LY LX MA MC MD MB ME MG MH MF MR MT MU MS MV MX MW JN D B -> Silhouette score: 0.541
#   Sequence: A C JM LN LQ LO LR LT LU LV LS LW LY LZ LX MA MD MC MB ME MI MK MJ MF MR MT MU MS MV MY MW JN D B -> Silhouette score: 0.560
#   Sequence: A C JM LN LP LO LR LU LV LT LS LW LZ LY LX MA MD MC MB ME MG MH MF MR MT MU MS MV MY MW JN D B -> Silhouette score: 0.563
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LZ LY LX MA MD MC MB ME MG MH MF MR MU MT MS MV MX MW JN D B -> Silhouette score: 0.585
#   Sequence: A C JM LN LP LO LR LU LT LV LS LW LY LZ LX MA MD MC MB ME MI ML MJ MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.562
#   Sequence: A C JM LN LP LO LR LU LT LV LS LW LY LZ LX MA MC MD MB ME MG MH MF MR MU MT MS MV MX MW JN D B -> Silhouette score: 0.555
#   Sequence: A C JM JO JU KD KB KE JW KC JY JX JV JP KF LF KQ KH LH KS KJ LI KK KU LG KT KI KR KL KP KN KO KM KG JN D B -> Silhouette score: 0.160
#   Sequence: A C JM LN LQ LO LR LU LT LV LS LW LY LZ LX MA MC MD MB ME MM MO MN MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.551
#   Sequence: A C JM LN LQ LO LR LU LV LT LS LW LZ LY LX MA MD MC MB ME MM MP MN MF MR MU MT MS MV MX MW JN D B -> Silhouette score: 0.540
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LY LZ LX MA MD MC MB ME MM MP MN MF MR MT MU MS MV MY MW JN D B -> Silhouette score: 0.576
#   Sequence: A C JM LN LP LO LR LT LU LV LS LW LZ LY LX MA MC MD MB ME MM MP MN MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.581
#   Sequence: A C JM LN LQ LO LR LT LU LV LS LW LY LZ LX MA MD MC MB ME MG MH MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.585
#   Sequence: A C JM JO JU KB KD JW KC JY KE JX JV JP KF KH LF KQ LH KW KJ KK LI LA KI LG KX KL KO KP KR KN KM KG JN D B -> Silhouette score: 0.150
#   Sequence: A C JM JO JQ JR JS JT JP KF LF KQ KH LJ KS KK LL KJ KU KT KI LK KR KL LG KO KP KN KM KG JN D B -> Silhouette score: 0.127
#   Sequence: A C JM JO JQ JR JS JT JP KF KQ KS KH LF KJ KK LH KU LI KT KI KR LG KL KO KN KP KM KG JN D B -> Silhouette score: 0.099
#   Sequence: A C JM LN LP LO LR LU LT LV LS LW LZ LY LX MA MD MC MB ME MG MH MF MR MU MT MS MV MY MW JN D B -> Silhouette score: 0.585
#
# Average silhouette score per cluster :
#   Medoid: A C E G T V X W U Y AA Z H AC AO AE AQ AG AR AI AP AH AS AF AV AT AD F D B -> Average score: -0.093
#   Medoid: A C E G T W X V U Y AB Z H AC AE AO AG AI AR AQ AH AP AF AS AV AT AD F D B -> Average score: 0.539
#   Medoid: A C JM LN LP LO LR LT LU LV LS LW LZ LY LX MA MD MC MB ME MG MH MF MR MU MT MS MV MY MW JN D B -> Average score: 0.466
#
# Overall silhouette score: 0.108

# %% [markdown]
# #### Exploring PMA (Progressive Multiple Alignment)

# %% [markdown]
# Here, we delve into the Progressive Multiple Alignment (PMA) technique as another approach to clustering sequences, providing additional insights and comparisons.
# The key idea of PMA is to iteratively build alignments by starting with the most similar pair of sequences (based here on a the edit distance) and progressively adding sequences to the alignment in order of similarity. This hierarchical approach allows us to construct a global representation of the relationships between sequences.

# %%
def pam(sequences, k, distance_fn, max_iter=100):
    medoids = random.sample(sequences, k)
    
    def total_cost(medoids, clusters):
        cost = 0
        for medoid, cluster in clusters.items():
            cost += sum(distance_fn(seq, medoid) for seq in cluster)
        return cost

    def assign_clusters(sequences, medoids):
        clusters = {medoid: [] for medoid in medoids}
        for seq in sequences:
            closest_medoid = min(medoids, key=lambda m: distance_fn(seq, m))
            clusters[closest_medoid].append(seq)
        return clusters

    clusters = assign_clusters(sequences, medoids)
    current_cost = total_cost(medoids, clusters)

    for iteration in range(max_iter):
        print(f"Iteration {iteration+1}")
        swap_occurred = False

        for medoid in medoids:
            for candidate in sequences:
                if candidate in medoids: 
                    continue
                
                # Tester le swap
                new_medoids = [m for m in medoids if m != medoid] + [candidate]
                new_clusters = assign_clusters(sequences, new_medoids)
                new_cost = total_cost(new_medoids, new_clusters)

                # Effectuer le swap si le coût est réduit
                if new_cost < current_cost:
                    medoids = new_medoids
                    clusters = new_clusters
                    current_cost = new_cost
                    swap_occurred = True
                    print(f"Swap performed : {medoid} -> {candidate}")
                    break 
            if swap_occurred:
                break 

        if not swap_occurred:
            print("No swap was performed, the algorithm converges.")
            break

    return clusters, medoids

# %%
sequences = load_sequences("log.txt", num_sequences=100)
k = 3
clusters, medoids = pam(sequences, k, edit_distance)

print("\nResults of PAM clustering  :")
for i, (medoid, cluster) in enumerate(clusters.items(), 1):
    print(f"Cluster {i} :")
    print(f"  Medoid: {medoid}")
    print(f"  Number of sequences: {len(cluster)}")
    print(f"  Sequences :")
    for seq in cluster:
        print(f"    {seq}")
    print("\n" + "-" * 50 + "\n")
# Out:
# Iteration 1
# Swap performed : A C EC FL FX FN FS FW GA FU FQ FR FV FP FY FO FT FM GC GE GJ GI GK GH GG GF GD GL GN GO GM GW HC HE HD GX ED D B -> A C JM LN LQ LO LR LV LU LT LS LW LY LZ LX MA MD MC MB ME MM MO MN MF MR MT MU MS MV MX MW JN D B
# Iteration 2
# Swap performed : A C EC FL FX FS FN FZ FV FW FY FU FR FP FQ FT FO FM GC GE GJ GG GK GH GI GF GD GL GN GO GM GW GY HA HB GZ GX ED D B -> A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FG FJ FK FI FH FA ED D B
# Iteration 3
# Swap performed : A C E G I P R Q J H AC AE AO AG AQ AR AJ AP AH AF AS AW AT AD F D B -> A C E G T V W X U Y AA Z H AC AE AO AG AQ AR AJ AP AH AS AF AW AT AD F D B
# Iteration 4
# Swap performed : A C JM LN LQ LO LR LV LU LT LS LW LY LZ LX MA MD MC MB ME MM MO MN MF MR MT MU MS MV MX MW JN D B -> A C JM LN LQ LO LR LU LT LV LS LW LY LZ LX MA MD MC MB ME MM MQ MN MF MR MU MT MS MV MY MW JN D B
# Iteration 5
# Swap performed : A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FG FJ FK FI FH FA ED D B -> A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FB FE FD FF FC FA ED D B
# Iteration 6
# Swap performed : A C E G T V W X U Y AA Z H AC AE AO AG AQ AR AJ AP AH AS AF AW AT AD F D B -> A C E G T V W X U Y AA Z H AC AE AO AG AQ AR AJ AP AH AS AF AV AT AD F D B
# Iteration 7
# Swap performed : A C JM LN LQ LO LR LU LT LV LS LW LY LZ LX MA MD MC MB ME MM MQ MN MF MR MU MT MS MV MY MW JN D B -> A C JM LN LP LO LR LU LT LV LS LW LY LZ LX MA MC MD MB ME MM MQ MN MF MR MT MU MS MV MY MW JN D B
# Iteration 8
# Swap performed : A C JM LN LP LO LR LU LT LV LS LW LY LZ LX MA MC MD MB ME MM MQ MN MF MR MT MU MS MV MY MW JN D B -> A C JM LN LQ LO LR LT LU LV LS LW LY LZ LX MA MD MC MB ME MG MH MF MR MT MU MS MV MY MW JN D B
# Iteration 9
# Swap performed : A C JM LN LQ LO LR LT LU LV LS LW LY LZ LX MA MD MC MB ME MG MH MF MR MT MU MS MV MY MW JN D B -> A C JM LN LP LO LR LU LT LV LS LW LY LZ LX MA MD MC MB ME MM MP MN MF MR MT MU MS MV MY MW JN D B
# Iteration 10
# Swap performed : A C JM LN LP LO LR LU LT LV LS LW LY LZ LX MA MD MC MB ME MM MP MN MF MR MT MU MS MV MY MW JN D B -> A C JM LN LP LO LR LU LT LV LS LW LY LZ LX MA MD MC MB ME MG MH MF MR MT MU MS MV MY MW JN D B
# Iteration 11
# No swap was performed, the algorithm converges.
#
# Results of PAM clustering  :
# Cluster 1 :
#   Medoid: A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FB FE FD FF FC FA ED D B
#   Number of sequences: 37
#   Sequences :
#     A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FG FJ FK FI FH FA ED D B
#     A C EC FL FX FS FN GA FU FV FW FR FQ FP FY FO FT FM GC GJ GE GK GG GI GH GF GD GL GP GQ GM GW HG HK HH GX ED D B
#     A C EC EE EG EH EF EN ER EP ES EQ EO ET EV EX EY EW EU EZ FB FE FF FD FC FA ED D B
#     A C EC FL FN FX FS FP FR FU FQ FZ FW FV FY FO FT FM GC GE GJ GK GI GG GH GF GD GL GN GO GM GW HG HK HH GX ED D B
#     A C EC FL FN FX FS GA FV FR FU FQ FW FP FT FY FO FM GC GJ GE GK GI GG GH GF GD GL GN GO GM GW GY HB HA GZ GX ED D B
#     A C EC HL IE IP IK IG IJ IT IM IS IR IH IL IQ IF HM IU JC JG JE JK JI JJ JF JH JL JD IV ED D B
#     A C EC HL IE IK IP IG IO IT IS IR II IL IH IQ IF HM IU JC JE JG JK JI JF JJ JH JL JD IV ED D B
#     A C EC HL HV IC ID HW HM IU IW IX IY JB IZ IV ED D B
#     A C EC FL FX FN FS FW GA FU FQ FR FV FP FY FO FT FM GC GE GJ GI GK GH GG GF GD GL GN GO GM GW HC HE HD GX ED D B
#     A C EC EE EG EH EF EN ER EP EQ ES EO ET EX EV EY EW EU EZ FB FF FD FE FC FA ED D B
#     A C EC EE EG EH EF EN EP ER EQ ES EO ET EX EV EY EW EU EZ FG FK FJ FI FH FA ED D B
#     A C EC EE EI EM EJ EF EN ER EP EQ ES EO ET EX EY EV EW EU EZ FB FD FF FE FC FA ED D B
#     A C EC FL FX FS FN FZ FV FW FY FU FR FP FQ FT FO FM GC GE GJ GG GK GH GI GF GD GL GN GO GM GW GY HA HB GZ GX ED D B
#
# --------------------------------------------------
#
# Cluster 2 :
#   Medoid: A C E G T V W X U Y AA Z H AC AE AO AG AQ AR AJ AP AH AS AF AV AT AD F D B
#   Number of sequences: 31
#   Sequences :
#     A C E G T V W X U Y AA Z H AC AE AO AG AQ AR AJ AP AH AS AF AW AT AD F D B
#     A C E G T V X W U Y AA Z H AC AE AO AG AQ AR AJ AP AH AF AS AW AT AD F D B
#     A C E G I P R Q J H AC AE AO AG AQ AR AJ AP AH AF AS AW AT AD F D B
#     A C E AX CR AZ CA DI CC BB CD DU CE BD DV CF BF DJ BG CB BE CS BC BA AY F D B
#     A C E G I P S Q J H AC AE AO AK AQ AR AN AM AP AL AS AF AV AT AD F D B
#     A C E AX AZ CA CR BM CG BO CT CI BR DE CL CK BP DH BN DG CJ BA DF CH CU CB CS AY F D B
#     A C E AX AZ CA CR CC BM DW BO CD EA DY CE BQ DZ EB CF BP DX BN CB CS BA AY F D B
#     A C E G T V W X U Y AA Z H AC AO AE AQ AK AR AN AP AM AL AS AF AV AT AD F D B
#     A C E G I P S Q J H AC AO AE AQ AK AR AN AP AM AL AS AF AU AT AD F D B
#     A C E AX CA AZ CR CC CT BB CD DE CE BD DG DH BF CF BG DF CU BE CB BC CS BA AY F D B
#     A C E AX CA AZ CR CG BB DI CI BH CK DK CL BK CJ DM DO DN BI CH DL DJ CB BC BA CS AY F D B
#     A C E G I P R Q J H AC AO AE AQ AR AG AJ AP AH AS AV AF AT AD F D B
#     A C E G I P S Q J H AC AO AE AQ AR AG AI AP AH AS AF AV AT AD F D B
#     A C E AX CA AZ CR DW CC BB CD DY BD EA CE DZ BF BG EB CF BE DX CB BC CS BA AY F D B
#     A C E G T W V X U Y AB Z H AC AO AE AG AR AQ AJ AP AH AF AS AU AT AD F D B
#     A C E AX AZ CA CR BB DI CG CI BH BK DK CL CK BI DM DO CJ DN BC CH DL BA CB DJ CS AY F D B
#     A C E G T X W V U Y AB Z H AC AE AO AG AQ AR AI AP AH AS AF AV AT AD F D B
